# %% [markdown]
# # Analyse de paroles de chansons
# ---
#
# Nous avons récupérer la quasi-totalité des paroles de plusieurs groupes depuis le site genius lyrics. Les paroles sont toutes les paroles d'une sélection de groupe qu'aime bien notre utilisateur. Nous allons analyser la qualité des données et voir ce qu'il est possible d'en déduire sur l'utilisateur.

# %% [markdown]
# ## Import des bibliothèques

# %%
from langdetect import detect
import pandas as pd
from profanity_check import predict

# %%
all_songs_df = pd.read_csv("all_songs.csv", sep=";")

# %%
all_songs_df["release_date"] = pd.to_datetime(all_songs_df["release_date"])

# %% [markdown]
# ## Analyse de la qualité
# ---
#  Nous allons voir s'il n'existe pas des chansons manquantes, vérifier la langue, quelles sont les dates des chansons et analyser le nombre de vues.

# %% [markdown]
# Analyse des colonnes numériques

# %%
# Apporte peu d'informations et oublie le fait que des valeurs sont vides
# On constate que seules les chansons avec des paroles récoltant de 5000 vues possèdent le nombre de vues (on remarque cela en regardant le min)
# Les chansons sont classées par ordre de popularité (déduisible en regardant les valeurs de lyrics-view).
all_songs_df.describe()
# Out:
#                         release_date   lyrics_view
# count                           3236  1.642000e+03
# mean   2013-06-06 05:32:51.322620416  3.749365e+04
# min              1993-12-14 00:00:00  5.001000e+03
# 25%              2008-06-24 00:00:00  9.085500e+03
# 50%              2013-11-22 00:00:00  1.615300e+04
# 75%              2018-10-19 00:00:00  3.423250e+04
# max              2023-12-29 00:00:00  1.179103e+06
# std                              NaN  6.787042e+04

# %%
# On construit la colonne "notoriety" quelles sont les titres les plus consultés du groupe
all_songs_df["notoriety"] = all_songs_df.groupby("band_name")["song_title"].transform('cumcount')
print(f"Sur notre jeu de données, {round(all_songs_df['lyrics_view'].isna().sum() / len(all_songs_df) * 100, 2)}% des chansons ne possèdent pas le nombre de vues.")
# Out:
# Sur notre jeu de données, 56.81% des chansons ne possèdent pas le nombre de vues.

# %% [markdown]
# Analyse des valeurs manquantes

# %%
# On constate qu'on dispose de paroles pour la plupart des chansons. On regarde rapidement celles dont les paroles sont manquantes.
all_songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3802 entries, 0 to 3801
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   band_name                 3802 non-null   object
#  1   song_title                3802 non-null   object
#  2   album_name                3574 non-null   object
#  3   lyrics                    3709 non-null   object
#  4   release_date              3236 non-null   datetime64[ns]
#  5   release_date_for_display  3330 non-null   object
#  6   lyrics_view               1642 non-null   float64
#  7   feat                      3802 non-null   object
#  8   is_feat                   3802 non-null   bool
#  9   primary_artist_name       3802 non-null   object
#  10  notoriety                 3802 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 300.9+ KB

# %%
# En regardant les morceaux sans paroles, on se rend compte qu'il s'agit de morceaux instrumentaux. Il est normal qu'il n'y ait pas de paroles.
all_songs_df.loc[all_songs_df["lyrics"].isna()].tail(30)
# Out:
#                   band_name  \
# 2489              Nightwish
# 2492              Nightwish
# 2528              Nightwish
# 2529              Nightwish
# 2636      Poets of the Fall
# 2666           Prime Circle
# 2722                  PVRIS
# 2727                  PVRIS
# 2903                STARSET
# 2987  Steam Powered Giraffe
# 3058              TesseracT
# 3171  The Birthday Massacre
# 3406        The Dear Hunter
# 3409        The Dear Hunter
# 3410        The Dear Hunter
# 3412        The Dear Hunter
# 3413        The Dear Hunter
# 3416        The Dear Hunter
# 3419        The Dear Hunter
# 3516           The National
# 3529           The National
# 3579           The National
# 3588           The National
# 3590           The National
# 3591           The National
# 3592           The National
# 3593           The National
# 3594           The National
# 3595           The National
# 3797      Within Temptation
#
#                                              song_title  \
# 2489  All The Works Of Nature Which Adorn The World ...
# 2492  All The Works Of Nature Which Adorn The World ...
# 2528                       Crimson Tide / Deep Blue Sea
# 2529                                           Elvenjig
# 2636                                              Rogue
# 2666                             Intro [All Or Nothing]
# 2722                        If I Don’t Wake Up Tomorrow
# 2727                                               Lung
# 2903                         UNVEILING THE ARCHITECTURE
# 2987                 Heist Ho! (SteamWorld Heist Theme)
# 3058               Concealing Fate Part Five - Epiphany
# 3171                                           Prologue
# 3406                Disrupter Sphere | Sprawl | Antimai
# 3409                                      To Your Cycle
# 3410                       Prayer | Uncle Boot | Breach
# 3412                              A Guide to Retrievals
# 3413                      Your Reward Is Not Tax Exempt
# 3416                                         Movement 2
# 3419                                         Movement 1
# 3516                             Her Father in the Pool
# 3529                                         Underwater
# 3579                                          San Mateo
# 3588                                             Ingrid
# 3590                                             Cooper
# 3591                                                Leo
# 3592                                               Leah
# 3593                                            Orourke
# 3594                                             Soglio
# 3595                                               Nova
# 3797                                          Intro [2]
#
#                           album_name lyrics release_date  \
# 2489             HUMAN. :||: NATURE.    NaN   2020-04-10
# 2492             HUMAN. :||: NATURE.    NaN   2020-04-10
# 2528         From Wishes to Eternity    NaN          NaT
# 2529  Decades - Live In Buenos Aires    NaN          NaT
# 2636                   Jealous Gods     NaN   2014-09-19
# 2666                  All or Nothing    NaN   2008-06-24
# 2722                             NaN    NaN          NaT
# 2727                             NaN    NaN   2017-08-04
# 2903                        HORIZONS    NaN   2021-10-22
# 2987     Music from SteamWorld Heist    NaN          NaT
# 3058                             One    NaN   2010-10-11
# 3171                          Violet    NaN   2004-10-25
# 3406                The Indigo Child    NaN   2021-10-22
# 3409                The Indigo Child    NaN   2021-10-22
# 3410                The Indigo Child    NaN   2021-10-22
# 3412                The Indigo Child    NaN   2021-10-22
# 3413                The Indigo Child    NaN   2021-10-22
# 3416        Act III: Life and Death     NaN          NaT
# 3419        Act III: Life and Death     NaN   2009-06-23
# 3516               I Am Easy to Find    NaN   2019-05-17
# 3529               I Am Easy to Find    NaN   2019-05-17
# 3579             Songs Without Words    NaN          NaT
# 3588             Songs Without Words    NaN          NaT
# 3590             Songs Without Words    NaN          NaT
# 3591             Songs Without Words    NaN          NaT
# 3592             Songs Without Words    NaN          NaT
# 3593             Songs Without Words    NaN          NaT
# 3594             Songs Without Words    NaN          NaT
# 3595             Songs Without Words    NaN          NaT
# 3797                The Silent Force    NaN   2004-11-11
#
#      release_date_for_display  lyrics_view feat  is_feat  \
# 2489           April 10, 2020          NaN   []    False
# 2492           April 10, 2020          NaN   []    False
# 2528                      NaN          NaN   []    False
# 2529                      NaN          NaN   []    False
# 2636       September 19, 2014          NaN   []    False
# 2666            June 24, 2008          NaN   []    False
# 2722                      NaN          NaN   []    False
# 2727           August 4, 2017          NaN   []    False
# 2903         October 22, 2021          NaN   []    False
# 2987                      NaN          NaN   []    False
# 3058         October 11, 2010          NaN   []    False
# 3171         October 25, 2004          NaN   []    False
# 3406         October 22, 2021          NaN   []    False
# 3409         October 22, 2021          NaN   []    False
# 3410         October 22, 2021          NaN   []    False
# 3412         October 22, 2021          NaN   []    False
# 3413         October 22, 2021          NaN   []    False
# 3416                      NaN          NaN   []    False
# 3419            June 23, 2009          NaN   []    False
# 3516             May 17, 2019      10611.0   []    False
# 3529             May 17, 2019       9360.0   []    False
# 3579                      NaN          NaN   []    False
# 3588                      NaN          NaN   []    False
# 3590                      NaN          NaN   []    False
# 3591                      NaN          NaN   []    False
# 3592                      NaN          NaN   []    False
# 3593                      NaN          NaN   []    False
# 3594                      NaN          NaN   []    False
# 3595                      NaN          NaN   []    False
# 3797        November 11, 2004          NaN   []    False
#
#         primary_artist_name  notoriety
# 2489              Nightwish         95
# 2492              Nightwish         98
# 2528              Nightwish        134
# 2529              Nightwish        135
# 2636      Poets of the Fall        101
# 2666           Prime Circle         24
# 2722                  PVRIS         55
# 2727                  PVRIS         60
# 2903                STARSET         57
# 2987  Steam Powered Giraffe         79
# 3058              TesseracT         44
# 3171  The Birthday Massacre        100
# 3406        The Dear Hunter        139
# 3409        The Dear Hunter        142
# 3410        The Dear Hunter        143
# 3412        The Dear Hunter        145
# 3413        The Dear Hunter        146
# 3416        The Dear Hunter        149
# 3419        The Dear Hunter        152
# 3516           The National         96
# 3529           The National        109
# 3579           The National        159
# 3588           The National        168
# 3590           The National        170
# 3591           The National        171
# 3592           The National        172
# 3593           The National        173
# 3594           The National        174
# 3595           The National        175
# 3797      Within Temptation        115

# %% [markdown]
# Analyse de la langue

# %%
def identify_language(x):
    try:
        return(detect(x))
    except:
        return("language_error")

all_songs_df["text_language"] = all_songs_df["lyrics"].apply(identify_language)
all_songs_df.loc[all_songs_df["lyrics"].isna(), "text_language"] = "no_lyrics"

# %%
# On constate que la majorité des paroles sont en anglais.
all_songs_df.groupby("text_language").count()["band_name"]
# Out:
# text_language
# af              1
# en           3704
# et              2
# fr              1
# no_lyrics      93
# sw              1
# Name: band_name, dtype: int64

# %%
# Sur les chansons notées comme n'étant pas en anglais, on constate qu'elles sont en anglais et il y en a une qui semble fausse (Tied up de PVRIS). On la supprime.
all_songs_df.loc[~all_songs_df["text_language"].isin(["en", "no_lyrics"])]
# Out:
#              band_name             song_title  \
# 1552             Foals             Providence
# 2132  Lord of the Lost         Digging Deeper
# 2171            Metric       Poster of a Girl
# 2270            Metric  I Don’t Wanna Wake Up
# 2729             PVRIS                Tied Up
#
#                                            album_name  \
# 1552                                        Holy Fire
# 2132                           Judas (Deluxe Edition)
# 2171                                      Live It Out
# 2270  Cosmopolis (Original Motion Picture Soundtrack)
# 2729                                              NaN
#
#                                                  lyrics release_date  \
# 1552  I know I cannot be true\nI'm an animal just li...   2013-02-08
# 2132  I'm digging in deeper\nI'm digging deeper\nI'm...   2021-07-02
# 2171  \nCan't stand by myself\nHate to sleep alone\n...   2006-05-15
# 2270  (Heavily distorted vocals)\nI don't wanna wake...          NaT
# 2729                   **soon**You might also likeEmbed          NaT
#
#      release_date_for_display  lyrics_view  \
# 1552         February 8, 2013       6458.0
# 2132             July 2, 2021          NaN
# 2171             May 15, 2006      13104.0
# 2270                     2012          NaN
# 2729                      NaN          NaN
#
#                                                    feat  is_feat  \
# 1552                                                 []    False
# 2132  [{'api_path': '/artists/1702821', 'header_imag...     True
# 2171                                                 []    False
# 2270                                                 []    False
# 2729                                                 []    False
#
#      primary_artist_name  notoriety text_language
# 1552               Foals         53            et
# 2132    Lord of the Lost        195            af
# 2171              Metric         11            fr
# 2270              Metric        110            sw
# 2729               PVRIS         62            et

# %%
all_songs_df = all_songs_df.loc[~((all_songs_df["song_title"] == "Tied Up") & (all_songs_df["band_name"] == "PVRIS"))]

# %% [markdown]
# Analyse des doublons

# %%
# On constate que tous les couples groupes / titres sont uniques. On ne devrait donc pas posséder de doublons.
all_songs_df.groupby(["band_name", "song_title"])["text_language"].count().sort_values(ascending=False)
# Out:
# band_name          song_title
# Amaranthe          1.000.000 Lightyears                           1
# PVRIS              Bad World                                      1
# Nightwish          White Night Fantasy                            1
#                    Whoever Brings the Night                       1
#                    Wish I Had an Angel                            1
#                                                                  ..
# Deftones           Pink Maggit                                    1
#                    Pittura Infamante                              1
#                    Please Please Please Let Me Get What I Want    1
#                    Poltergeist                                    1
# Within Temptation  Worth Dying For                                1
# Name: text_language, Length: 3801, dtype: int64

# %%
all_songs_df.to_csv("all_songs_df.csv", index=False, sep=";")

# %% [markdown]
# # Analyse des données
# ---
#
# Toutes les chansons reflètent les goûts d'un utilisateur. Que peut-on dire des groupes puis de cet utilisateur ?

# %% [markdown]
# Afin de pouvoir faire notre analyse, nous allons construire un dataset des groupes qui inclue le nombre de chansons, nombre d'albums, nombre maximal de vues, date premier album et dernier album...

# %%
group_df = pd.DataFrame(all_songs_df.groupby("band_name")["song_title"].count())

# %% [markdown]
# Nombre d'albums et d'EP

# %%
# On se rend compte que le nombre d'albums ne sera pas facile à obtenir car on possède des versions alternatives d'un même album et des singles
all_songs_df.dropna(subset="album_name").groupby("band_name")["album_name"].unique().iloc[0]
# Out:
# array(['Helix', 'Amaranthe', 'Massive Addictive', 'Manifest', 'The Nexus',
#        'Maximalism', 'PvP (Remix) - Single', ' Manifest (Bonus Version) ',
#        'The Catalyst', 'Communio Lupatum'], dtype=object)

# %%
group_df["album_list"] = all_songs_df.dropna(subset="album_name").groupby("band_name")["album_name"].unique()
group_df["num_album"] = group_df["album_list"].apply(lambda x : len([title for title in x if (("live at" not in title.lower()) & ("version" not in title.lower()) & ("single" not in title.lower()) & ("session" not in title.lower()) & ("edition" not in title.lower()))]))

# %% [markdown]
# Plus petite et plus grande date de publication

# %%
group_df["smallest_date"] = all_songs_df.groupby("band_name")["release_date"].min()
group_df["biggest_date"] = all_songs_df.groupby("band_name")["release_date"].max()

# %% [markdown]
# Nombre maximal de vues

# %%
group_df["max_view"] = all_songs_df.groupby("band_name")["lyrics_view"].max()

# %% [markdown]
# Nombre de feats

# %%
group_df["num_feat"] = all_songs_df.groupby("band_name")["is_feat"].sum()

# %% [markdown]
# Vérification de la vulgarité
#
# Quels sont les groupes les plus vulgaires ?

# %%
all_songs_df["has_profanity"] = all_songs_df["lyrics"].fillna("").apply(lambda x : predict([x])[0])

# %%
all_songs_df.groupby("has_profanity")["band_name"].count()
# Out:
# has_profanity
# 0    3256
# 1     545
# Name: band_name, dtype: int64

# %%
group_df["profanity_count"] = all_songs_df.groupby("band_name")["has_profanity"].sum().sort_values(ascending=False)
group_df["profanity_ratio"] = group_df["profanity_count"] / group_df["song_title"]

# %%
group_df
# Out:
#                          song_title  \
# band_name
# Amaranthe                        83
# Anthony Green                    79
# Architects                      127
# Bad Omens                        40
# Blue October                    175
# Brand New                        85
# Breaking Benjamin                80
# Bring Me The Horizon            125
# CHVRCHES                         76
# Circa Survive                   103
# Coheed and Cambria              137
# Dayseeker                        71
# Deftones                        148
# Don Broco                        70
# Earthside                        14
# Fightstar                        86
# Foals                           117
# Jason Isbell                     54
# Katatonia                       180
# La Dispute                       87
# Lord of the Lost                223
# Metric                          130
# My Chemical Romance             104
# Nightwish                       141
# PVRIS                            63
# Poets of the Fall               107
# Prime Circle                     25
# STARSET                          62
# Sleep Token                      50
# Soen                             65
# Steam Powered Giraffe           106
# TesseracT                        57
# The Birthday Massacre           118
# The Dangerous Summer             78
# The Dear Hunter                 153
# The National                    178
# There Will Be Fireworks          44
# VOLA                             40
# Within Temptation               120
#
#                                                                 album_list  \
# band_name
# Amaranthe                [Helix, Amaranthe, Massive Addictive, Manifest...
# Anthony Green            [Pixie Queen, Studio 4 Acoustic Session, Would...
# Architects               [Holy Hell, All Our Gods Have Abandoned Us, Li...
# Bad Omens                [THE DEATH OF PEACE OF MIND, Bad Omens, Findin...
# Blue October             [Foiled, History For Sale, I Hope You’re Happy...
# Brand New                [The Devil and God Are Raging Inside Me, Deja ...
# Breaking Benjamin        [Phobia, Ember, Dark Before Dawn, We Are Not A...
# Bring Me The Horizon     [Live at Wembley, POST HUMAN: SURVIVAL HORROR,...
# CHVRCHES                 [The Bones of What You Believe (Special Editio...
# Circa Survive            [On Letting Go, The Amulet, Juturna, Blue Sky ...
# Coheed and Cambria       [Good Apollo, I’m Burning Star IV, Volume One:...
# Dayseeker                [Sleeptalk, Dark Sun, Dreaming Is Sinking /// ...
# Deftones                 [White Pony , Around the Fur, Diamond Eyes, Sa...
# Don Broco                [Technology, Amazing Things, ACTION - Single, ...
# Earthside                         [A Dream In Static, Let the Truth Speak]
# Fightstar                [Behind The Devil’s Back, They Liked You Bette...
# Foals                    [What Went Down, Total Life Forever, Holy Fire...
# Jason Isbell             [Southeastern, Something More Than Free, Siren...
# Katatonia                [The Great Cold Distance, The Fall of Hearts, ...
# La Dispute               [Wildlife, Somewhere at the Bottom of the Rive...
# Lord of the Lost         [Thornstar (Deluxe Edition), Die Tomorrow, Fro...
# Metric                   [Greatest Hits Vol. 1, Synthetica, Pagans in V...
# My Chemical Romance      [The Black Parade (Deluxe Version), Three Chee...
# Nightwish                [Once, HUMAN. :||: NATURE., Endless Forms Most...
# PVRIS                    [All We Know of Heaven, All We Need of Hell, W...
# Poets of the Fall        [Carnival of Rust, Twilight Theater, Ultraviol...
# Prime Circle             [Evidence, All or Nothing, Jekyll & Hyde, Hell...
# STARSET                  [Transmissions , Vessels, DIVISIONS, HORIZONS,...
# Sleep Token              [Take Me Back To Eden, This Place Will Become ...
# Soen                     [Lykaia, Lotus, IMPERIAL, Cognitive, Tellurian...
# Steam Powered Giraffe    [The 2¢ Show, Album One, The Vice Quadrant: A ...
# TesseracT                [Polaris, Altered State, Sonder, One, War of B...
# The Birthday Massacre    [Walking With Strangers, Under Your Spell, Not...
# The Dangerous Summer     [Reach for the Sun, The Dangerous Summer, Moth...
# The Dear Hunter          [Act IV: Rebirth in Reprise, Act V: Hymns With...
# The National             [First Two Pages of Frankenstein, Trouble Will...
# There Will Be Fireworks  [The Dark, Dark Bright, There Will Be Firework...
# VOLA                     [Witness, Applause of a Distant Crowd, Inmazes...
# Within Temptation        [Resist (Extended Deluxe), Hydra, The Heart of...
#
#                          num_album smallest_date biggest_date   max_view  \
# band_name
# Amaranthe                        8    2009-02-18   2023-11-16    11113.0
# Anthony Green                    9    2008-08-05   2023-05-13    28210.0
# Architects                      13    2006-05-15   2023-12-04   232410.0
# Bad Omens                        4    2015-12-18   2022-02-25    97665.0
# Blue October                    14    2000-08-15   2023-10-13   457485.0
# Brand New                        9    2001-10-09   2017-08-17   303815.0
# Breaking Benjamin                9    2002-08-27   2019-12-06   204551.0
# Bring Me The Horizon            13    2003-10-02   2023-10-13   435778.0
# CHVRCHES                        10    2012-11-05   2023-10-20   221424.0
# Circa Survive                   17    2005-03-18   2022-02-04    46402.0
# Coheed and Cambria              14    2002-03-05   2022-06-24   156565.0
# Dayseeker                        7    2013-10-06   2022-11-04    53303.0
# Deftones                        16    1995-10-03   2021-10-26   321357.0
# Don Broco                        5    2008-11-04   2023-09-15    31599.0
# Earthside                        2    2015-10-23   2023-11-17    11917.0
# Fightstar                        8    2005-02-25   2015-10-16        NaN
# Foals                           10    2006-03-27   2023-04-21   171319.0
# Jason Isbell                     8    2007-06-10   2021-10-08   174579.0
# Katatonia                       18    1993-12-14   2023-01-20    21315.0
# La Dispute                      15    2006-04-14   2021-12-24   159338.0
# Lord of the Lost                14    2009-08-28   2023-12-29    13788.0
# Metric                          20    2003-09-02   2023-11-17   292326.0
# My Chemical Romance             20    2002-05-27   2022-05-12  1179103.0
# Nightwish                       21    1997-11-01   2021-08-06    71994.0
# PVRIS                            9    2013-01-01   2023-07-14    82828.0
# Poets of the Fall               12    2005-01-19   2022-04-29    61504.0
# Prime Circle                     5    2008-06-24   2017-09-22        NaN
# STARSET                          6    2013-05-13   2022-08-19   129993.0
# Sleep Token                      6    2016-09-08   2023-05-19   157254.0
# Soen                             9    2012-02-05   2023-09-01    27708.0
# Steam Powered Giraffe            7    2009-10-30   2021-11-26    63720.0
# TesseracT                        8    2010-09-16   2023-09-15    30656.0
# The Birthday Massacre           12    2002-07-23   2022-02-18    12191.0
# The Dangerous Summer             9    2009-05-05   2022-08-26    11355.0
# The Dear Hunter                 14    2005-01-01   2022-07-01    20748.0
# The National                    23    2001-01-01   2023-09-18   267566.0
# There Will Be Fireworks          4    2011-01-01   2023-12-01        NaN
# VOLA                             5    2010-03-22   2023-08-23     7707.0
# Within Temptation               12    1997-04-07   2023-10-20    36823.0
#
#                          num_feat  profanity_count  profanity_ratio
# band_name
# Amaranthe                       5                4         0.048193
# Anthony Green                   5               11         0.139241
# Architects                     10               33         0.259843
# Bad Omens                       0               10         0.250000
# Blue October                    4               36         0.205714
# Brand New                       0                6         0.070588
# Breaking Benjamin               2               24         0.300000
# Bring Me The Horizon           23               56         0.448000
# CHVRCHES                        2                7         0.092105
# Circa Survive                   2                7         0.067961
# Coheed and Cambria              3               39         0.284672
# Dayseeker                       8               17         0.239437
# Deftones                       11               41         0.277027
# Don Broco                       1               17         0.242857
# Earthside                      13                0         0.000000
# Fightstar                       0               13         0.151163
# Foals                           0                3         0.025641
# Jason Isbell                    0                5         0.092593
# Katatonia                       5               12         0.066667
# La Dispute                      2                6         0.068966
# Lord of the Lost               31               54         0.242152
# Metric                          1               12         0.092308
# My Chemical Romance             3               33         0.317308
# Nightwish                       0               13         0.092199
# PVRIS                           4               12         0.190476
# Poets of the Fall               0                2         0.018692
# Prime Circle                    0                1         0.040000
# STARSET                         2                4         0.064516
# Sleep Token                     0                4         0.080000
# Soen                            1                0         0.000000
# Steam Powered Giraffe           1                7         0.066038
# TesseracT                       1                3         0.052632
# The Birthday Massacre           0                7         0.059322
# The Dangerous Summer            1                7         0.089744
# The Dear Hunter                20                9         0.058824
# The National                   12               17         0.095506
# There Will Be Fireworks         0                0         0.000000
# VOLA                            1                1         0.025000
# Within Temptation              14               12         0.100000

# %%
group_df.to_csv("group_df.csv", index=True, sep=";")

# %% [markdown]
# ## Bilan 1)
# ---
#
# Que sait-on de cet utilisateur ?
#
# La plupart des groupes datent des années 2000 / 2010 et semblent encore être en activité (au moins un album dans les cinq dernières années). En terme de vues, quelques groupes semblent inconnus (aucune chanson avec plus de 5000 vues). Pour un certain nombre de groupe, on a moins de 10 chasons par albums ce qui semble plutôt indiquer des chansons longues ou beaucoup d'EP ?
